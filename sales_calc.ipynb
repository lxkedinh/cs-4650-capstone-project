# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from math import exp
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

games = pd.read_csv('games.csv')

# %%
games.head()
# Out:
#      AppID                   Name  Release date Estimated owners  Peak CCU  \
# 0    20200       Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370           Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930           Jolt Project  Nov 17, 2021        0 - 20000         0
# 3  1355720               Henosis™  Jul 23, 2020        0 - 20000         0
# 4  1139950  Two Weeks in Painland   Feb 3, 2020        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
# 3             0   5.99          0
# 4             0   0.00          0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
# 3  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# ...

# %%
actionGenre = games[games.Genres == 'Action']
actionGenre
# Out:
#          AppID                                          Name  Release date  \
# 15       22670                        Alien Breed 3: Descent  Nov 17, 2010
# 66       12140                                     Max Payne   Jan 6, 2011
# 77     1621490                                   MagicShop3D  Jun 19, 2022
# 116     730310                            DYNASTY WARRIORS 9  Feb 13, 2018
# 117     242530                              The Chaos Engine  Aug 29, 2013
# ...        ...                                           ...           ...
# 83360  2414900                           Soulknight Survivor   Dec 1, 2023
# 83389  1686940                                   Bopl Battle  Nov 16, 2023
# 83438  2609760                                      EMZOMBED   Oct 3, 2023
# 83490  2554950                                         Raioh   Oct 6, 2023
# 83537  2131630  METAL GEAR SOLID - Master Collection Version  Oct 24, 2023
#
# ...

# %%
actionMax = actionGenre["Estimated owners"].max()
actionMax
# Out:
# '5000000 - 10000000'

# %%
actionMaxInfo = actionGenre.loc[actionGenre["Estimated owners"] == '5000000 - 10000000']
actionMaxInfo
# Out:
#         AppID                                     Name  Release date  \
# 2444      300                    Day of Defeat: Source  Jul 12, 2010
# 2758      420                 Half-Life 2: Episode Two  Oct 10, 2007
# 3636       30                            Day of Defeat   May 1, 2003
# 8413   250900            The Binding of Isaac: Rebirth   Nov 4, 2014
# 9907       80           Counter-Strike: Condition Zero   Mar 1, 2004
# 14759  976730        Halo: The Master Chief Collection   Dec 3, 2019
# 19555      20                    Team Fortress Classic   Apr 1, 1999
# 21910    8870                        BioShock Infinite  Mar 25, 2013
# 33441     360             Half-Life Deathmatch: Source   May 1, 2006
# 34209      40                       Deathmatch Classic   Jun 1, 2001
# 34638      60                                 Ricochet   Nov 1, 2000
# 37547  883710                          Resident Evil 2  Jan 24, 2019
# 39055      50                Half-Life: Opposing Force   Nov 1, 1999
# ...

# %%
advGenre = games[games.Genres == 'Adventure']
advGenre
# Out:
#          AppID                                               Name  \
# 87     1131550                        I Walk Among Zombies Vol. 3
# 139     572330                                            The Fan
# 142     700880                           Kingdom: The Far Reaches
# 368    1580990                      Manipulator I:The Hand Behind
# 404     757600           Hotel Transylvania 3: Monsters Overboard
# ...        ...                                                ...
# 83103  2407400                        Molly Medusa: Queen of Spit
# 83184  2625700                          The Semen Donation Truck!
# 83345  2392160                                         Abscission
# 83442  2479010  The Coming End: Fresh Force Frustrations (A Ga...
# 83500  2451980                                     Gold and Glory
#
#        Release date Estimated owners  Peak CCU  Required age  Price  \
# 87     Dec 15, 2020        0 - 20000         2             0  14.99
# ...

# %%
advMax = advGenre["Estimated owners"].max()
advMax
# Out:
# '5000000 - 10000000'

# %%
advMaxInfo = advGenre.loc[advGenre["Estimated owners"] == '5000000 - 10000000']
advMaxInfo
# Out:
#         AppID                      Name  Release date    Estimated owners  \
# 13247   15700  Oddworld: Abe's Oddysee®  Aug 28, 2008  5000000 - 10000000
# 30925  532210         Life is Strange 2  Sep 26, 2018  5000000 - 10000000
#
#        Peak CCU  Required age  Price  DLC count  \
# 13247        12             0   2.99          0
# 30925       249             0   0.00          6
#
#                                           About the game  \
# 13247  Selected by the fickle finger of fate, Abe™, f...
# 30925  ALL EPISODES ARE AVAILABLE TO PLAY NOW! Purcha...
#
#                                      Supported languages  ...  \
# 13247  ['English', 'French', 'German', 'Italian', 'Ja...  ...
# 30925  ['English', 'French', 'Italian', 'German', 'Sp...  ...
#
#       Average playtime two weeks Median playtime forever  \
# 13247                          0                     232
# 30925                          0                     199
#
#       Median playtime two weeks  \
# ...

# %%
casualGenre = games[games.Genres == 'Casual']
casualGenre
# Out:
#          AppID                                Name  Release date  \
# 7      1968760  Legend of Rome - The Wrath of Mars   May 5, 2022
# 26      677880                      Draw Your Game  Aug 10, 2017
# 27     1294780               Pathfinders: Memories  Feb 16, 2021
# 36     1095380     Bepuzzled Kittens Jigsaw Puzzle  Jun 11, 2019
# 63     1684530         100 Doors: Escape from Work   Mar 1, 2022
# ...        ...                                 ...           ...
# 83387  2642980    Block Breakin' Logic Downstacker   Dec 1, 2023
# 83444  2420710                   Volatile Particle  Nov 15, 2023
# 83452  2443990                    Engaging Destiny   Oct 2, 2023
# 83509  2531760                  Daily Exercise App  Aug 10, 2023
# 83557  2308790                            UNDRESS!  Oct 23, 2023
#
#       Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 7            0 - 20000         2             0   9.99          0
# ...

# %%
casualMax = casualGenre["Estimated owners"].max()
casualMax
# Out:
# '500000 - 1000000'

# %%
casualMaxInfo = casualGenre.loc[casualGenre["Estimated owners"] == '500000 - 1000000']
casualMaxInfo
# Out:
#         AppID            Name Release date  Estimated owners  Peak CCU  \
# 31820  562810  MONOPOLY® PLUS  Sep 7, 2017  500000 - 1000000       236
#
#        Required age  Price  DLC count  \
# 31820             0  14.99          0
#
#                                           About the game  \
# 31820  A real living board: • A full 3D city at the c...
#
#                                      Supported languages  ...  \
# 31820  ['English', 'French', 'Italian', 'German', 'Sp...  ...
#
#       Average playtime two weeks Median playtime forever  \
# 31820                        146                     282
#
#       Median playtime two weeks    Developers Publishers  \
# 31820                       147  Ubisoft Pune    Ubisoft
#
#                                               Categories  Genres  \
# 31820  Single-player,Multi-player,PvP,Online PvP,Shar...  Casual
#
#                                                     Tags  \
# 31820  Multiplayer,Board Game,Casual,Tabletop,Family ...
#
# ...

# %%
indieGenre = games[games.Genres == 'Indie']
indieMax = indieGenre["Estimated owners"].max()
indieMax
# Out:
# '500000 - 1000000'

# %%
indieMaxInfo = indieGenre.loc[indieGenre["Estimated owners"] == '500000 - 1000000']
indieMaxInfo
# Out:
#          AppID                                  Name  Release date  \
# 1316      1530                            Multiwinia  Sep 19, 2008
# 4820   1892810                        Fishy Business  Feb 21, 2022
# 4917    736260                           Baba Is You  Mar 13, 2019
# 7101   1288310                              Firework   Feb 3, 2021
# 10651   220780                      Thomas Was Alone  Nov 12, 2012
# 11761   205910     Tiny and Big: Grandpa's Leftovers  Jun 19, 2012
# 16085   332800             Five Nights at Freddy's 2  Nov 10, 2014
# 20925  1349230  5D Chess With Multiverse Time Travel  Jul 22, 2020
# 30010   405640                           Pony Island   Jan 4, 2016
# 45564   607260                                 McOsu  Mar 20, 2017
#
#        Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 1316   500000 - 1000000         2             0   9.99          0
# 4820   500000 - 1000000         0             0  24.99          0
# ...

# %%
sportsGenre = games[games.Genres == 'Sports']
sportsMax = sportsGenre["Estimated owners"].max()
sportsMax
# Out:
# '500000 - 1000000'

# %%
sportsMaxInfo = sportsGenre.loc[sportsGenre["Estimated owners"] == '500000 - 1000000']
sportsMaxInfo
# Out:
#         AppID                            Name  Release date  Estimated owners  \
# 29207  485610          Ball 3D: Soccer Online  Mar 31, 2017  500000 - 1000000
# 30523  950100  PRO EVOLUTION SOCCER 2019 LITE  Dec 13, 2018  500000 - 1000000
# 42712  592600  PRO EVOLUTION SOCCER 2018 LITE  Nov 15, 2017  500000 - 1000000
# 77226  385760                        NBA 2K17  Sep 20, 2016  500000 - 1000000
#
#        Peak CCU  Required age  Price  DLC count  \
# 29207       159             0   9.99          0
# 30523         4             0   0.00          0
# 42712         1             0   0.00          0
# 77226        88             0   0.00          0
#
#                                           About the game  \
# 29207  Features Multiplayer 11 Game modes 21 Stadiums...
# 30523  A free-to-play version of 'PES 2019' is here!*...
# 42712  A free-to-play version of 'PES 2018' is here!*...
# 77226  Following the record-breaking launch of NBA 2K...
#
# ...

# %%
stratGenre = games[games.Genres == 'Strategy']
stratMax = stratGenre["Estimated owners"].max()
stratMax
# Out:
# '5000000 - 10000000'

# %%
stratMaxInfo = stratGenre.loc[stratGenre["Estimated owners"] == '5000000 - 10000000']
stratMaxInfo
# Out:
#         AppID                          Name  Release date    Estimated owners  \
# 6262   221380      Age of Empires II (2013)   Apr 9, 2013  5000000 - 10000000
# 11843    8930   Sid Meier's Civilization® V  Sep 21, 2010  5000000 - 10000000
# 40756  231430           Company of Heroes 2  Jun 25, 2013  5000000 - 10000000
# 49224  289070  Sid Meier’s Civilization® VI  Oct 20, 2016  5000000 - 10000000
# 59333  268500                       XCOM® 2   Feb 4, 2016  5000000 - 10000000
#
#        Peak CCU  Required age  Price  DLC count  \
# 6262       4638             0  19.99          3
# 11843     21665             0  29.99         15
# 40756      7055            17  19.99          5
# 49224     37024             0  59.99          9
# 59333      4731             0   8.99          7
#
#                                           About the game  \
# 6262   In Age of Empires II: HD Edition, fans of the ...
# 11843  The Flagship Turn-Based Strategy Game Returns ...
# ...

# %%
simGenre = games[games.Genres == 'Simulation']
simMax = simGenre["Estimated owners"].max()
simMax
# Out:
# '500000 - 1000000'

# %%
simMaxInfo = simGenre.loc[simGenre["Estimated owners"] == '500000 - 1000000']
simMaxInfo
# Out:
#          AppID                                               Name  \
# 9211   1250410  Microsoft Flight Simulator Game of the Year Ed...
# 11808   270850                        Car Mechanic Simulator 2014
# 16330   313160                               Farming Simulator 15
# 17008    17440                    SPORE™ Creepy & Cute Parts Pack
# 18556   515180                                   Bus Simulator 18
# 24480   573090                       Stormworks: Build and Rescue
# 29724   442120                                        Pinball FX3
# 45609   397720                Romance of the Three Kingdoms Maker
# 49333   269950                                         X-Plane 11
# 58731   641320                                  Cooking Simulator
# 58755   446800                                    Transport Fever
#
#        Release date  Estimated owners  Peak CCU  Required age  Price  \
# 9211   Apr 17, 2020  500000 - 1000000      6991             0  59.99
# ...

# %%
rpgGenre = games[games.Genres == 'RPG']
rpgMax = rpgGenre["Estimated owners"].max()
rpgMax
# Out:
# '5000000 - 10000000'

# %%
rpgMaxInfo = rpgGenre.loc[rpgGenre["Estimated owners"] == '5000000 - 10000000']
rpgMaxInfo
# Out:
#          AppID                                         Name  Release date  \
# 10646    72850                  The Elder Scrolls V: Skyrim  Nov 10, 2011
# 34805   377160                                    Fallout 4   Nov 9, 2015
# 48127   489830  The Elder Scrolls V: Skyrim Special Edition  Oct 27, 2016
# 79530  1716740                                    Starfield   Sep 5, 2023
#
#          Estimated owners  Peak CCU  Required age  Price  DLC count  \
# 10646  5000000 - 10000000      4383            17  19.99          1
# 34805  5000000 - 10000000     23636            17  19.99          9
# 48127  5000000 - 10000000     26777            17  39.99          1
# 79530  5000000 - 10000000     16006            17  69.99          2
#
#                                           About the game  \
# 10646  EPIC FANTASY REBORN The next chapter in the hi...
# 34805  Bethesda Game Studios, the award-winning creat...
# 48127  Winner of more than 200 Game of the Year Award...
# ...
